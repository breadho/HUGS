# %% [markdown]
# # HUGS
#
# HST UV Globular Cluster Survey
#
#
# > 참고자료
# >    - https://github.com/laingmic005/aperture-photometry/blob/main/L1_fits-handling.ipynb
# >    - https://youtu.be/_DzSIeruotQ?si=ScAl1J5rSqyIt_ap
# >    - https://archive.stsci.edu/prepds/hugs/
# >    - https://archive.stsci.edu/proposal_search.php?id=13297&mission=hst
# >    - https://archive.stsci.edu/proposal_search.php?id=10775&mission=hst

# %% [markdown]
# **소개**
#
# 대형 레거시 재무부 프로그램 "The HST Legacy Survey of Galactic Globular Clusters: Shedding UV Light on Their Populations and Formation"(GO-13297, PI: G. Piotto, 131 궤도)는 자외선/청색 WFC3/UVIS 필터 F275W, F336W 및 F438W를 통해 대규모 샘플의 성단을 이미지화하여 "은하 구상성단의 ACS 조사"(GO-10775, PI: A. Sarajedini, 134 궤도)의 기존 F606W 및 F814W 데이터베이스의 보완을 위한 UV 이니셔티브 제안서입니다. 이 세 가지 필터는 C, N, O 농도 변화에 민감하기 때문에 구상성단의 여러 집단을 분리하고 특성을 파악할 수 있습니다. 이러한 자외선/청색 필터와 광학 필터를 함께 사용하면 각 집단의 헬륨 함량을 측정할 수 있습니다.
#
# 최종 데이터베이스에는 GO-13297 (PI: Piotto)과 두 개의 파일럿 프로젝트인 GO-12311 (PI: Piotto) 및 GO-12605 (PI: Piotto) 동안 관측된 56개의 구상성단과 1개의 개방성단의 카탈로그와 천체 관측 스택 이미지가 포함되어 있습니다. 각 클러스터에 대해 채택된 광도 측정 방법마다 하나씩 3개의 카탈로그를 공개합니다. 카탈로그에는 성단 필드에서 발견된 각 별의 위치와 5개 대역(F275W, F336W, F438W, F606W, F814W)의 광도 측정에 대한 정보가 포함되어 있습니다. 카탈로그에는 구성원 확률도 포함되어 있습니다. HUGS 데이터 제품 전체 컬렉션은 DOI http://dx.doi.org/10.17909/T9810F 에서 참조할 수 있습니다.
#
# **데이터 액세스**
#
# 아래 표의 필터 열에 있는 다양한 노출 시간에 대해 스택 FITS 이미지를 사용할 수 있습니다. 세 가지 방법 각각에 대한 카탈로그 파일과 색상 크기 다이어그램 및 RGB 색상 이미지도 표에서 확인할 수 있습니다(RGB 이미지는 크기가 커서 브라우저에 완전히 표시되는 데 시간이 오래 걸릴 수 있습니다). 마지막으로, 마지막 열에는 특정 클러스터의 모든 파일을 다운로드하려는 사용자를 위해 특정 클러스터에 대한 모든 데이터 제품이 포함된 .tar.gz 파일이 포함되어 있습니다. 참고: 팀 홈페이지( http://groups.dfa.unipd.it/ESPG/treasury.php)에서도 동일한 데이터를 검색할 수 있습니다.

# %% [markdown]
# **`대상 천체`**
#
# Cluster	  |       RA  |        Dec. | (Observable in UJB)
# :----------|-----------:|-------------:|:----------------:|
# NGC 0104|	6.023792 |	-72.081306| X |
# NGC 0288|	13.188500|	-26.582611| O |
# NGC 0362|	15.809417|	-70.848778| X |
# NGC 1261|	48.067542|	-55.216222| X |
# NGC 1851|	78.528167|	-40.046556| O |
# NGC 2298|	102.247542|	-36.005306| O |
# NGC 2808|	138.012917|	-64.863500| X |
# NGC 3201|	154.403417|	-46.412472| O |
# NGC 4590|	189.866583|	-26.744056| O |
# NGC 4833|	194.891333|	-70.876500| X |
# NGC 5024|	198.230208|	18.168167| O |
# NGC 5053|	199.112875|	17.700250| O |
# NGC 5272|	205.548417|	28.377278| O |
# NGC 5286|	206.611708|	-51.374250| O |
# NGC 5466|	211.363708|	28.534444| O |
# NGC 5897|	229.351667|	-21.010111| O |
# NGC 5904|	229.638417|	2.081028| O |
# NGC 5927|	232.002875|	-50.673028| O |
# NGC 5986|	236.512500|	-37.786417| O |
# NGC 6093|	244.260042|	-22.976083| O |
# NGC 6101|	246.450500|	-72.202194| X |
# NGC 6121|	245.896750|	-26.525750| O |
# NGC 6144|	246.807750|	-26.023500| O |
# NGC 6171|	248.132750|	-13.053778| O |
# NGC 6205|	250.421833|	36.459861| O |
# NGC 6218|	251.809083|	-1.948528| O |
# NGC 6254|	254.287708|	-4.100306| O |
# NGC 6304|	258.634375|	-29.462028| O |
# NGC 6341|	259.280792|	43.135944| O |
# NGC 6352|	261.371292|	-48.422167| O |
# NGC 6362|	262.979125|	-67.048333| X |
# NGC 6366|	261.934333|	-5.079861| O |
# NGC 6388|	264.071792|	-44.735500| O |
# NGC 6397|	265.175375|	-53.674333| X |
# NGC 6441|	267.554417|	-37.051444| O |
# NGC 6496|	269.765333|	-44.265944| O |
# NGC 6535|	270.960458|	-0.297639| O |
# NGC 6541|	272.009833|	-43.714889| O |
# NGC 6584|	274.656667|	-52.215778| O |
# NGC 6624|	275.918792|	-30.361028| O |
# NGC 6637|	277.846250|	-32.348083| O |
# NGC 6652|	278.940125|	-32.990722| O |
# NGC 6656|	279.099750|	-23.904750| O |
# NGC 6681|	280.803167|	-32.292111| O |
# NGC 6715|	283.763875|	-30.479861| O |
# NGC 6717|	283.775167|	-22.701472| O |
# NGC 6723|	284.888125|	-36.632250| O |
# NGC 6752|	287.717125|	-59.984556| X |
# NGC 6779|	289.148208|	30.183472| O |
# NGC 6791|	290.220833|	37.771667| O |
# NGC 6809|	294.998792|	-30.964750| O |
# NGC 6838|	298.443708|	18.779194| O |
# NGC 6934|	308.547375|	7.404472| O |
# NGC 6981|	313.365417|	-12.537306| O |
# NGC 7078|	322.493042|	12.167000| O |
# NGC 7089|	323.362583|	-0.823250| O |
# NGC 7099|	325.092167|	-23.179861| O |

# %% [markdown]
# **HUGS** 에 사용된 필터 종류
#
# F275W, F336W, F435W, F438W, F606W, F814W
#
# **`필터 종류 설명`**
#
# > **HUGS에 사용된 허블 우주망원경 필터**
# > - F275W: 0.275 마이크로미터 파장 사용 보라색으로 표시 (UV)
# > - F336W: 0.435 마이크로미터 파장 사용 파란색으로 표시 (blue WFC3)
# > - F438W: 0.438 마이크로미터 파장 사용 (UVIS)
# > - F606W: 0.606 마이크로미터 파장 사용 (가시광 영역, V band)
# > - F814W: 0.814 마이크로미터 파장 사용 (적외선 근접 영역)
#
# > 각 필터는 고유한 중심 파장과 통과하는 빛의 범위를 가지며, 다양한 천체 및 천체 현상을 연구하는 데 사용됩니다.
#
# > F275W 필터 (UV)
# >
# > 이 필터는 약 275nm의 중심 파장을 가지며, 주로 자외선(UV) 영역의 빛을 측정합니다. 별의 핫 스팟, 활동성 은하 핵, 또는 영역 내에서의 별 생성과 같은 고에너지 현상을 연구하는 데 유용합니다. 천체의 활발한 별 생성 영역이나 강력한 자외선을 방출하는 젊은 별들을 관찰하는 데 특히 유용합니다.
#
# > F336W 필터 (U)
# >
# > 중심 파장이 약 336nm인 이 필터는 가시광선에 가까운 자외선 영역의 빛을 포착합니다. 'U' 밴드 필터로 알려져 있으며, 별의 온도, 금속성, 그리고 별간 먼지의 효과 등을 연구하는 데 사용됩니다. 주로 별의 화학적 조성과 구조를 연구하는 데 중요한 도구로 활용됩니다.
#
# > F438W 필터 (B)
# >
# > 이 필터는 약 438nm의 중심 파장을 가지며, 'B' 밴드에 해당하는 파란색 빛을 관찰합니다. 주로 별의 온도와 진화 단계를 연구하며, 별의 밝기와 색상을 측정하는 데 사용됩니다. 은하의 구조와 별들의 분포를 이해하는 데도 중요한 역할을 합니다.
#
# > F606W 필터(V)
# >
# > - 중심 파장과 범위: F606W 필터는 약 606nm의 중심 파장에서 빛을 통과시킵니다. 이는 가시광선 스펙트럼 중 녹색에서 빨간색 사이의 범위에 해당합니다.
# > - 주요 사용 목적: 이 필터는 주로 별과 은하의 색상과 밝기를 측정하는 데 사용됩니다. 천문학자들은 이 데이터를 통해 천체의 연령, 조성, 거리 및 기타 중요한 물리적 특성을 결정할 수 있습니다.
# > - 특징적 연구 분야: F606W 필터는 별의 진화, 은하의 구조, 그리고 적색편이를 포함한 우주의 거대 구조에 대한 연구에 널리 사용됩니다. 또한, 천체 사진에서 상세한 색상 정보를 제공하여, 다른 필터와 결합될 때 더욱 풍부한 정보를 얻을 수 있습니다.
# > - 관측 효율성: "Wide V" 필터로도 알려진 F606W는 넓은 파장 범위를 통과시켜 상대적으로 밝은 이미지를 생성합니다. 이로 인해, 더 먼 천체나 약한 광원도 효과적으로 관찰할 수 있습니다.
#
# > F814W 필터 (I)
# >
# > 중심 파장이 약 814nm인, 이 필터는 가시광선의 빨간색 끝에 해당하는 'I' 밴드의 빛을 캡처합니다. 별과 은하의 구성 및 거리 측정에 사용되며, 더 먼 천체나 먼지로 인해 빛이 흐려진 천체의 관찰에 유용합니다. 별의 진화 및 은하의 연령 추정에 중요한 데이터를 제공합니다.
#
#
# **일목요연한 정리**
#
# > **F275W (UV)**
# >
# > - 중심 파장: 약 275nm
# > - 색상 범위: 자외선(UV)
# > - 주요 사용: 별 생성 지역, 핫 스타, 활성 은하 핵
# > - 특징: 고에너지 현상 관찰에 유용
#
# > **F336W (U)**
# >
# > - 중심 파장: 약 336nm
# > - 색상 범위: 자외선에 가까운 가시광선
# > - 주요 사용: 별의 온도, 금속성, 별간 먼지 연구
# > - 특징: 별의 화학 조성 및 구조 연구에 중요
#
# > **F438W (B)**
# >
# > - 중심 파장: 약 438nm
# > - 색상 범위: 파란색 가시광선 (B 밴드)
# > - 주요 사용: 별의 온도 및 진화 단계, 은하 구조
# > - 특징: 별과 은하의 색상과 밝기 측정에 유용
#
# > **F606W (Wide V)**
# >
# > - 중심 파장: 약 606nm
# > - 색상 범위: 녹색에서 빨간색 사이의 가시광선
# > - 주요 사용: 별과 은하의 색상과 밝기 측정
# > - 특징: 적색편이 연구 및 별의 진화에 중요
#
# > **F814W (I)**
# >
# > - 중심 파장: 약 814nm
# > - 색상 범위: 빨간색 끝 가시광선 (I 밴드)
# > - 주요 사용: 거리 측정, 먼지로 가려진 천체 관찰
# > - 특징: 별과 은하의 구성 및 연령 추정에 중요

# %% [markdown]
# 허블 우주 망원경의 F275W, F336W, F438W, F606W, F814W 필터 각각에 대해 더 자세하게 설명드리겠습니다.
#
# > 1. F275W 필터 (UV)
#     - 중심 파장: 약 275nm
#     - 색상 범위: 자외선
#     - 주요 사용: 이 필터는 특히 핫 스타, 활성 은하 핵, 별 생성 지역 등의 고에너지 현상을 관찰하는 데 사용됩니다. 자외선 영역에서의 별과 은하의 활동을 연구하여, 별의 초기 단계와 먼 은하의 세부 사항을 포착하는 데 중요합니다.
#     - 특징: 자외선 영역에서 강한 별이나 은하의 빛을 감지함으로써, 천체의 온도, 화학적 조성, 밀도 등을 파악할 수 있습니다.
#
# > 2. F336W 필터 (U)
#     - 중심 파장: 약 336nm
#     - 색상 범위: 자외선에 가까운 가시광선
#     - 주요 사용: 별의 온도, 금속성, 그리고 별간 먼지의 효과를 연구하는 데 사용됩니다. 이 필터는 별과 은하의 자외선 방출 특성을 이해하는 데 중요한 역할을 하며, 별의 연령 및 진화 상태에 대한 정보를 제공합니다.
#     - 특징: 별의 화학적 조성과 대기 특성을 이해하는 데 특히 유용하며, 청색 초거성 및 젊은 별들의 활동을 포착할 수 있습니다.
#
# > 3. F438W 필터 (B)
#     - 중심 파장: 약 438nm
#     - 색상 범위: 파란색 가시광선
#     - 주요 사용: 별의 온도와 진화 단계를 이해하는 데 주로 사용됩니다. 은하의 구조와 별의 분포를 파악하는 데 중요하며, 별과 은하의 색상 및 밝기 변화를 측정하는 데 유용합니다.
#     - 특징: 별의 온도가 높을수록 더 밝게 나타나며, 별이나 은하의 색상 그라디언트를 통해 연령과 구성을 추정할 수 있습니다.
#
# > 4. F606W 필터 (Wide V)
#     - 중심 파장: 약 606nm
#     - 색상 범위: 녹색에서 빨간색 사이의 가시광선
#     - 주요 사용: 별과 은하의 색상과 밝기를 측정하는 데 널리 사용됩니다. 특히, 적색편이가 큰 은하의 관찰이나 별의 진화 연구에 유용합니다.
#     - 특징: 다양한 천체의 색상과 밝기 정보를 제공하며, 별의 연령과 거리 측정에 중요한 데이터를 제공합니다. 또한, 넓은 파장 범위를 포착하여 밝고 선명한 이미지를 생성합니다.
#
# > 5. F814W 필터 (I)
#     - 중심 파장: 약 814nm
#     - 색상 범위: 빨간색 끝 가시광선
#     - 주요 사용: 이 필터는 별과 은하의 구성을 연구하고, 특히 먼지로 인해 가려진 천체나 멀리 떨어진 천체의 관찰에 유용합니다. 별의 연령 추정 및 은하의 거리 측정에 중요한 역할을 합니다.
#     - 특징: 빛의 적외선에 가까운 부분을 포착하여, 먼지로 가려진 지역이나 먼 천체의 관찰에 유리합니다. 또한, 별의 진화 상태 및 은하의 구성을 파악하는 데 중요한 정보를 제공합니다.

# %%
from IPython.display import Image

Image('image/spect.png')

# %% [markdown]
# **`허블 기기 약자 설명`**
# >
# > - **(WFC3)** Wide Field Camera 3 (WFC3)
# > - **(COS)** Cosmic Origins Spectrograph (COS)
# > - **(ACS)** Advanced Camera for Surveys (ACS)
# > - **(STIS)** Space Telescope Imaging Spectrograph (STIS)
# > - **(FGS)** Fine Guidance Sensors (FGS).

# %%
Image('image/HubbleFOV.jpeg')

# %%
Image('image/Hubble1.jpeg')

# %% [markdown]
# **`파일명 명명방식`**
#
# > `HLSP_HUGS_HST_<INS>_<TARG>_<FILT>_V1_<EXTEN>`
# >
# > - `<ins>` = 기기 이름("acs-wfc", "wfc3-uvis" 또는 "wfc3-uvis-acs-wfc")
# > - `<targ>` = 대상 클러스터(예: "ngc6791")
# > - `<filt>` = 사용된 필터(예: "f606w", 일부 파일 형식의 경우 "multi")
# >- `<exteng>` = 파일 확장자, 다음에 해당합니다:
#     + stack-????s.fits: 스택 이미지를 얻는 데 사용된 이미지 중 가장 깊은 노출 시간으로 보고된 특정 필터에 대한 스택 이미지입니다.
#     + catalog-meth?.txt: 주어진 광도 측정 방법으로 얻은 천체 광도 측정 카탈로그
#     + cmd.png: F275W와 F275W-F336W의 색상 크기 다이어그램 예시
#     + rgb.tif: F275W, F336W, F438W 스택 이미지로 얻은 클러스터의 RGB 이미지

# %%
import os

# 대상 폴더 경로 설정
folder_path = '/Users/younghokim/astro/HUGS'

# 폴더 내의 모든 파일 및 폴더 목록을 가져옴
files = os.listdir(folder_path)
files_sorted = sorted(files, reverse = False)

print(files_sorted)

'''
# 모든 파일명 출력
for file in files_sorted:
#     if file.endswith('.fits'):
        print(file)
'''
# Out:
# ['.DS_Store', 'ngc0104', 'ngc0288', 'ngc0362', 'ngc1261', 'ngc1851', 'ngc2298', 'ngc2808', 'ngc3201', 'ngc4590', 'ngc4833', 'ngc5024', 'ngc5053', 'ngc5272', 'ngc5286', 'ngc5466', 'ngc5897', 'ngc5904', 'ngc5927', 'ngc5986', 'ngc6093', 'ngc6101', 'ngc6121', 'ngc6144', 'ngc6171', 'ngc6205', 'ngc6218', 'ngc6254', 'ngc6304', 'ngc6341', 'ngc6352', 'ngc6362', 'ngc6366', 'ngc6388', 'ngc6397', 'ngc6441', 'ngc6496', 'ngc6535', 'ngc6541', 'ngc6584', 'ngc6624', 'ngc6637', 'ngc6652', 'ngc6656', 'ngc6681', 'ngc6715', 'ngc6717', 'ngc6723', 'ngc6752', 'ngc6779', 'ngc6791', 'ngc6809', 'ngc6838', 'ngc6934', 'ngc6981', 'ngc7078', 'ngc7089', 'ngc7099']
# "\n# 모든 파일명 출력\nfor file in files_sorted:\n#     if file.endswith('.fits'):\n        print(file)\n"

# %%
# 폴더 내의 모든 파일 및 폴더 목록을 가져옴
files = os.listdir('/Users/younghokim/astro/HUGS/ngc0288')

# 모든 파일명 출력
for file in files:
    if file.endswith('.png'):
        print(file)
# Out:
# hlsp_hugs_hst_wfc3-uvis_ngc0288_multi_v1_rgb.png
# hlsp_hugs_hst_wfc3-uvis_ngc0288_multi_v1_cmd.png

# %% [markdown]
# ## NGC 104
#
# ### NGC104 Introduction
# NGC 104, 더 널리 알려진 이름으로 47 Tucanae 또는 47 Tuc,는 남쪽 하늘에 있는 밝고 거대한 구상성단입니다. 여기에는 몇 가지 중요한 특징들이 있습니다:
#
#
# 1. **위치와 발견:**
#  - 47 Tucanae는 남쪽 별자리인 Tucana (투칸새)에 위치해 있습니다. 유럽인에 의해 1751년 Nicolas-Louis de Lacaille에 의해 처음 기록되었습니다. 지구에서 약 13,000 광년 떨어져 있으며, 밤하늘에서 쉽게 볼 수 있는 밝은 천체 중 하나입니다.
#
# 2. **구성과 특성:**
#  - 이 성단은 수백만 개의 별로 구성되어 있으며, 대부분은 구상성단 내에서 집단적으로 나이가 들어가는 별들입니다. 별들은 중력에 의해 밀집되어 있으며, 성단 중심부는 특히 별들이 더욱 밀집되어 있습니다.
# 구상성단은 일반적으로 우리 은하계에서 가장 오래된 별 집단 중 하나로 여겨지며, 47 Tuc 역시 대략 120억 년 이상의 나이로 추정됩니다.
#
# 3. **관측:**
#  - 47 Tucanae는 맨눈으로 볼 수 있을 정도로 밝으며, 남반구에서 특히 잘 보입니다. 아마추어 천문학자들에게도 인기 있는 관측 대상이며, 작은 망원경을 사용하면 성단의 밀집된 별 구조를 더욱 세밀하게 볼 수 있습니다.
#
# 4. **과학적 중요성:**
#  - 47 Tuc은 천문학자들에게 중요한 연구 대상입니다. 구상성단은 은하 진화, 별 집단의 역동성, 그리고 별의 진화와 같은 다양한 천문학적 문제를 이해하는 데 도움을 줍니다.
# 또한, 성단 내에서 다수의 변광성, 밀리초 펄서 등 흥미로운 천체들이 발견되었습니다. 이는 천체물리학의 다양한 측면을 연구하는 데 중요한 정보를 제공합니다.

# %% [markdown]
# ### NGC104 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc0104/hlsp_hugs_hst_wfc3-uvis_ngc0104_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC104 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc0104/hlsp_hugs_hst_wfc3-uvis_ngc0104_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC288
#
# ### NGC288 Introduction
#
# 1. 위치와 거리: NGC 288은 남쪽 하늘에 위치한 조각가자리(Sculptor constellation) 방향에 있으며, 지구로부터 약 29,200광년 떨어져 있습니다.
#
# 2. 발견: 이 성단은 18세기 후반에 윌리엄 허셜에 의해 발견되었습니다.
#
# 3. 특징: NGC 288은 상대적으로 느슨한 구조를 가진 구상성단으로 알려져 있습니다. 이는 중심부의 별들이 다른 구상성단에 비해 덜 밀집되어 있다는 것을 의미합니다. 이러한 느슨한 구조는 그것의 진화 상태나 초기 조건에 대한 단서를 제공할 수 있습니다.
#
# 4. 별의 구성: 이 성단은 주로 노란색 및 빨간색 거성들로 이루어져 있으며, 이는 별들이 진화의 상당히 늦은 단계에 있음을 나타냅니다. NGC 288 내의 별들은 수십억 년의 나이로 추정됩니다.
#
# 5. 연구의 중요성: 천문학자들은 NGC 288과 같은 구상성단을 연구하여 별의 진화, 은하계의 초기 조건, 그리고 우주의 나이 등에 대해 이해를 높입니다. 또한, 구상성단은 다양한 천문학적 현상과 동적 과정을 연구하는데 중요한 대상이기도 합니다.
#
# [출처: chatgpt]

# %% [markdown]
# ### NGC288 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc0288/hlsp_hugs_hst_wfc3-uvis_ngc0288_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC288 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc0288/hlsp_hugs_hst_wfc3-uvis_ngc0288_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC362
#
# ### NGC362 Introduction
#
# **(황새치 자리 구상성단)**
#
# 1. 위치와 거리: NGC 362는 남쪽 하늘에 위치한 투카나자리(Tucana)에 있으며, 우리 은하계 중심에서 약 27,700광년 떨어진 곳에 위치합니다.
#
# 2. 발견: 이 구상성단은 1751년에 제임스 던롭(James Dunlop)에 의해 발견되었습니다.
#
# 3. 특징: NGC 362는 비교적 밝고, 중심부가 뚜렷이 조밀한 구상성단입니다. 이 성단은 또한 구상성단으로서는 드물게 금속성이 높은 별들을 많이 포함하고 있어, 별의 구성과 진화에 대한 중요한 단서를 제공합니다.
#
# 4. 별의 구성: 이 구상성단은 수십억 년 된 별들로 구성되어 있으며, 그 중 다수는 진화의 후기 단계인 적색거성 단계에 있습니다. 별들의 색과 밝기를 통해 천문학자들은 성단의 나이와 진화 상태를 추정할 수 있습니다.
#
# 5. 연구의 중요성: NGC 362는 구상성단의 연구에 중요한 대상 중 하나입니다. 그것의 별들은 은하계의 초기 조건과 별의 진화 과정에 대한 통찰력을 제공하며, 성단 내에서의 동적인 상호작용을 이해하는 데도 중요합니다.
#
# 6. 관측: NGC 362는 중간 크기의 망원경으로 관측할 수 있으며, 맑고 어두운 하늘에서는 세부적인 구조를 관찰할 수 있습니다. 천문학자들은 더 큰 망원경과 세밀한 분석을 통해 성단의 별들을 개별적으로 연구하기도 합니다.

# %% [markdown]
# ### NGC362 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc0362/hlsp_hugs_hst_wfc3-uvis_ngc0362_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC362 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc0362/hlsp_hugs_hst_wfc3-uvis_ngc0362_multi_v1_cmd.png" width="600" height="600">

# %% [markdown]
# ## NGC1261
#
# ### NGC1261 Introduction

# %% [markdown]
# ### NGC1261 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc1261/hlsp_hugs_hst_wfc3-uvis_ngc1261_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC1261 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc1261/hlsp_hugs_hst_wfc3-uvis_ngc1261_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC1851
#
# ### NGC1851 Introduction

# %% [markdown]
# ### NGC1851 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc1851/hlsp_hugs_hst_wfc3-uvis_ngc1851_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC1851 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc1851/hlsp_hugs_hst_wfc3-uvis_ngc1851_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC2298
#
# ### NGC2298 Introduction

# %% [markdown]
# ### NGC2298 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc2298/hlsp_hugs_hst_wfc3-uvis_ngc2298_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC2298 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc2298/hlsp_hugs_hst_wfc3-uvis_ngc2298_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC2808
#
# ### NGC2808 Introduction

# %% [markdown]
# ### NGC2808 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc2808/hlsp_hugs_hst_wfc3-uvis_ngc2808_multi_v1_rgb.png"
#     width="600"
#     height="600"/>

# %% [markdown]
# ### NGC2808 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc2808/hlsp_hugs_hst_wfc3-uvis_ngc2808_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC3201
#
# ### NGC3201 Introduction

# %% [markdown]
# ### NGC3201 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc3201/hlsp_hugs_hst_wfc3-uvis_ngc3201_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC3201 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc3201/hlsp_hugs_hst_wfc3-uvis_ngc3201_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC4590
#
# ### NGC4590 Introduction

# %% [markdown]
# ### NGC4590 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc4590/hlsp_hugs_hst_wfc3-uvis_ngc4590_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC4590 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc4590/hlsp_hugs_hst_wfc3-uvis_ngc4590_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC4833
#
# ### NGC4833 Introduction

# %% [markdown]
# ### NGC4833 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc4833/hlsp_hugs_hst_wfc3-uvis_ngc4833_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC4833 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc4833/hlsp_hugs_hst_wfc3-uvis_ngc4833_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC5024
#
# ### NGC5024 Introduction

# %% [markdown]
# ### NGC5024 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5024/hlsp_hugs_hst_wfc3-uvis_ngc5024_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC5024 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5024/hlsp_hugs_hst_wfc3-uvis_ngc5024_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC5053
#
# ### NGC5053 Introduction

# %% [markdown]
# ### NGC5053 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5053/hlsp_hugs_hst_wfc3-uvis_ngc5053_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC5053 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5053/hlsp_hugs_hst_wfc3-uvis_ngc5053_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC5272
#
# ### NGC5272 Introduction

# %% [markdown]
# ### NGC5272 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5272/hlsp_hugs_hst_wfc3-uvis_ngc5272_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC5272 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5272/hlsp_hugs_hst_wfc3-uvis_ngc5272_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC5286
#
# ### NGC5286 Introduction

# %% [markdown]
# ### NGC5286 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5286/hlsp_hugs_hst_wfc3-uvis_ngc5286_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC5286 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5286/hlsp_hugs_hst_wfc3-uvis_ngc5286_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC5466
#
# ### NGC5466 Introduction

# %% [markdown]
# ### NGC5466 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5466/hlsp_hugs_hst_wfc3-uvis_ngc5466_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC5466 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5466/hlsp_hugs_hst_wfc3-uvis_ngc5466_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC5897
#
# ### NGC5897 Introduction

# %% [markdown]
# ### NGC5897 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5897/hlsp_hugs_hst_wfc3-uvis_ngc5897_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC5897 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5897/hlsp_hugs_hst_wfc3-uvis_ngc5897_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC5904
#
# ### NGC5904 Introduction

# %% [markdown]
# ### NGC5904 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5904/hlsp_hugs_hst_wfc3-uvis_ngc5904_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC5904 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5904/hlsp_hugs_hst_wfc3-uvis_ngc5904_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC5927
#
# ### NGC5927 Introduction

# %% [markdown]
# ### NGC5927 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5927/hlsp_hugs_hst_wfc3-uvis_ngc5927_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC5927 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5927/hlsp_hugs_hst_wfc3-uvis_ngc5927_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC5986
#
# ### NGC5986 Introduction

# %% [markdown]
# ### NGC5986 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5986/hlsp_hugs_hst_wfc3-uvis_ngc5986_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC5986 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc5986/hlsp_hugs_hst_wfc3-uvis_ngc5986_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6093
#
# ### NGC6093 Introduction

# %% [markdown]
# ### NGC6093 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6093/hlsp_hugs_hst_wfc3-uvis_ngc6093_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6093 CMD
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6093/hlsp_hugs_hst_wfc3-uvis_ngc6093_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6101
#
# ### NGC6101 Introduction

# %% [markdown]
# ### NGC6101 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6101/hlsp_hugs_hst_wfc3-uvis_ngc6101_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6101 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6101/hlsp_hugs_hst_wfc3-uvis_ngc6101_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6121
#
# ### NGC6121 Introduction

# %% [markdown]
# ### NGC6121 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6121/hlsp_hugs_hst_wfc3-uvis_ngc6121_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6121 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6121/hlsp_hugs_hst_wfc3-uvis_ngc6121_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6144
#
# ### NGC6144 Introduction

# %% [markdown]
# ### NGC6144 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6144/hlsp_hugs_hst_wfc3-uvis_ngc6144_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6144 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6144/hlsp_hugs_hst_wfc3-uvis_ngc6144_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6171
#
# ### NGC6171 Introduction

# %% [markdown]
# ### NGC6171 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6171/hlsp_hugs_hst_wfc3-uvis_ngc6171_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6171 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6171/hlsp_hugs_hst_wfc3-uvis_ngc6171_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6205
#
# ### NGC6205 Introduction

# %% [markdown]
# ### NGC6205 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6205/hlsp_hugs_hst_wfc3-uvis_ngc6205_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6205 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6205/hlsp_hugs_hst_wfc3-uvis_ngc6205_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6218
#
# ### NGC6218 Introduction

# %% [markdown]
# ### NGC6218 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6218/hlsp_hugs_hst_wfc3-uvis_ngc6218_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6218 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6218/hlsp_hugs_hst_wfc3-uvis_ngc6218_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6254
#
# ### NGC6254 Introduction

# %% [markdown]
# ### NGC6254 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6254/hlsp_hugs_hst_wfc3-uvis_ngc6254_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6254 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6254/hlsp_hugs_hst_wfc3-uvis_ngc6254_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6304
#
# ### NGC6304 Introduction

# %% [markdown]
# ### NGC6304 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6304/hlsp_hugs_hst_wfc3-uvis_ngc6304_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6304 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6304/hlsp_hugs_hst_wfc3-uvis_ngc6304_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6341
#
# ### NGC6341 Introduction

# %% [markdown]
# ### NGC6341 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6341/hlsp_hugs_hst_wfc3-uvis_ngc6341_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6341 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6341/hlsp_hugs_hst_wfc3-uvis_ngc6341_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6352
#
# ### NGC6352 Introduction

# %% [markdown]
# ### NGC6352 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6352/hlsp_hugs_hst_wfc3-uvis_ngc6352_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6352 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6352/hlsp_hugs_hst_wfc3-uvis_ngc6352_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6362
#
# ### NGC6362 Introduction

# %% [markdown]
# ### NGC6362 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6362/hlsp_hugs_hst_wfc3-uvis_ngc6362_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6362 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6362/hlsp_hugs_hst_wfc3-uvis_ngc6362_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6366
#
# ### NGC6366 Introduction

# %% [markdown]
# ### NGC6366 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6366/hlsp_hugs_hst_wfc3-uvis_ngc6366_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6366 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6366/hlsp_hugs_hst_wfc3-uvis_ngc6366_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6388
#
# ### NGC6388 Introduction

# %% [markdown]
# ### NGC6388 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6388/hlsp_hugs_hst_wfc3-uvis_ngc6388_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6388 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6388/hlsp_hugs_hst_wfc3-uvis_ngc6388_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6397
#
# ### NGC6397 Introduction

# %% [markdown]
# ### NGC6397 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6397/hlsp_hugs_hst_wfc3-uvis_ngc6397_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6397 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6397/hlsp_hugs_hst_wfc3-uvis_ngc6397_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6441
#
# ### NGC6441 Introduction

# %% [markdown]
# ### NGC6441 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6441/hlsp_hugs_hst_wfc3-uvis_ngc6441_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6441 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6441/hlsp_hugs_hst_wfc3-uvis_ngc6441_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6496
#
# ### NGC6496 Introduction

# %% [markdown]
# ### NGC6496 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6496/hlsp_hugs_hst_wfc3-uvis_ngc6496_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6496 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6496/hlsp_hugs_hst_wfc3-uvis_ngc6496_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6535
#
# ### NGC6535 Introduction

# %% [markdown]
# ### NGC6535 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6535/hlsp_hugs_hst_wfc3-uvis_ngc6535_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6535 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6535/hlsp_hugs_hst_wfc3-uvis_ngc6535_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6541
#
# ### NGC6541 Introduction

# %% [markdown]
# ### NGC6541 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6541/hlsp_hugs_hst_wfc3-uvis_ngc6541_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6541 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6541/hlsp_hugs_hst_wfc3-uvis_ngc6541_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6584
#
# ### NGC6584 Introduction

# %% [markdown]
# ### NGC6584 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6584/hlsp_hugs_hst_wfc3-uvis_ngc6584_multi_v1_rgb.png" width ="600" height="600"/>

# %% [markdown]
# ### NGC6584 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6584/hlsp_hugs_hst_wfc3-uvis_ngc6584_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6624
#
# ### NGC6624 Introduction

# %% [markdown]
# ### NGC6624 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6624/hlsp_hugs_hst_wfc3-uvis_ngc6624_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6624 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6624/hlsp_hugs_hst_wfc3-uvis_ngc6624_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6637
#
# ### NGC6637 Introduction

# %% [markdown]
# ### NGC6637 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6637/hlsp_hugs_hst_wfc3-uvis_ngc6637_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6637 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6637/hlsp_hugs_hst_wfc3-uvis_ngc6637_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6652
#
# ### NGC6652 Introduction

# %% [markdown]
# ### NGC6652 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6652/hlsp_hugs_hst_wfc3-uvis_ngc6652_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6652 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6652/hlsp_hugs_hst_wfc3-uvis_ngc6652_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6656
#
# ### NGC6656 Introduction

# %% [markdown]
# ### NGC6656 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6656/hlsp_hugs_hst_wfc3-uvis_ngc6656_multi_v1_rgb.png" width="600" height="600">

# %% [markdown]
# ### NGC6656 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6656/hlsp_hugs_hst_wfc3-uvis_ngc6656_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6681
#
# ### NGC6681 Introduction

# %% [markdown]
# ### NGC6681 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6681/hlsp_hugs_hst_wfc3-uvis_ngc6681_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6681 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6681/hlsp_hugs_hst_wfc3-uvis_ngc6681_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6715
#
# ### NGC6715 Introduction

# %% [markdown]
# ### NGC6715 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6715/hlsp_hugs_hst_wfc3-uvis_ngc6715_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6715 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6715/hlsp_hugs_hst_wfc3-uvis_ngc6715_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6717
#
# ### NGC6717 Introduction

# %% [markdown]
# ### NGC6717 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6717/hlsp_hugs_hst_wfc3-uvis_ngc6717_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6717 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6717/hlsp_hugs_hst_wfc3-uvis_ngc6717_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6723
#
# ### NGC6723 Introduction

# %% [markdown]
# ### NGC6723 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6723/hlsp_hugs_hst_wfc3-uvis_ngc6723_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC104 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6723/hlsp_hugs_hst_wfc3-uvis_ngc6723_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6752
#
# ### NGC6752 Introduction

# %% [markdown]
# ### NGC6752 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6752/hlsp_hugs_hst_wfc3-uvis_ngc6752_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6752 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6752/hlsp_hugs_hst_wfc3-uvis_ngc6752_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6779
#
# ### NGC6779 Introduction

# %% [markdown]
# ### NGC6779 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6779/hlsp_hugs_hst_wfc3-uvis_ngc6779_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6779 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6779/hlsp_hugs_hst_wfc3-uvis_ngc6779_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6791
#
# ### NGC6791 Introduction

# %% [markdown]
# ### NGC6791 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6791/hlsp_hugs_hst_wfc3-uvis_ngc6791_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6791 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6791/hlsp_hugs_hst_wfc3-uvis_ngc6791_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6809
#
# ### NGC6809 Introduction

# %% [markdown]
# ### NGC6809 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6809/hlsp_hugs_hst_wfc3-uvis_ngc6809_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6809 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6809/hlsp_hugs_hst_wfc3-uvis_ngc6809_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6838
#
# ### NGC6838 Introduction

# %% [markdown]
# ### NGC6838 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6838/hlsp_hugs_hst_wfc3-uvis_ngc6838_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6838 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6838/hlsp_hugs_hst_wfc3-uvis_ngc6838_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6934
#
# ### NGC6934 Introduction

# %% [markdown]
# ### NGC6934 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6934/hlsp_hugs_hst_wfc3-uvis_ngc6934_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6934 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6934/hlsp_hugs_hst_wfc3-uvis_ngc6934_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC6981
#
# ### NGC6981 Introduction

# %% [markdown]
# ### NGC6981 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6981/hlsp_hugs_hst_wfc3-uvis_ngc6981_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC6981 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc6981/hlsp_hugs_hst_wfc3-uvis_ngc6981_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC7078
#
# ### NGC7078 Introduction

# %% [markdown]
# ### NGC7078 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc7078/hlsp_hugs_hst_wfc3-uvis_ngc7078_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC7078 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc7078/hlsp_hugs_hst_wfc3-uvis_ngc7078_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC7089
#
# ### NGC7089 Introduction

# %% [markdown]
# ### NGC7089 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc7089/hlsp_hugs_hst_wfc3-uvis_ngc7089_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC7089 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc7089/hlsp_hugs_hst_wfc3-uvis_ngc7089_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## NGC7099
#
# ### NGC7099 Introduction

# %% [markdown]
# ### NGC7099 RGB image
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc7099/hlsp_hugs_hst_wfc3-uvis_ngc7099_multi_v1_rgb.png" width="600" height="600"/>

# %% [markdown]
# ### NGC7099 CMD
#
# <img src="https://archive.stsci.edu/hlsps/hugs/ngc7099/hlsp_hugs_hst_wfc3-uvis_ngc7099_multi_v1_cmd.png" width="600" height="600"/>

# %% [markdown]
# ## The end
